# %% [markdown]
# # Data Cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:\\Users\\Shouq\\Downloads\\bank\\bank-full.csv')
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.shape
# Out:
# (45211, 17)

# %%
df.rename({'y':'deposit'},axis=1,inplace=True)
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  deposit    45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ## Checking the unique values

# %%
for col in df.columns:
    print(col)
    print(df[col].unique())
# Out:
# age
# [58 44 33 47 35 28 42 43 41 29 53 57 51 45 60 56 32 25 40 39 52 46 36 49
#  59 37 50 54 55 48 24 38 31 30 27 34 23 26 61 22 21 20 66 62 83 75 67 70
#  65 68 64 69 72 71 19 76 85 63 90 82 73 74 78 80 94 79 77 86 95 81 18 89
#  84 87 92 93 88]
# job
# ['management' 'technician' 'entrepreneur' 'blue-collar' 'unknown'
#  'retired' 'admin.' 'services' 'self-employed' 'unemployed' 'housemaid'
#  'student']
# marital
# ['married' 'single' 'divorced']
# education
# ['tertiary' 'secondary' 'unknown' 'primary']
# default
# ['no' 'yes']
# balance
# [ 2143    29     2 ...  8205 14204 16353]
# housing
# ['yes' 'no']
# loan
# ['no' 'yes']
# contact
# ['unknown' 'cellular' 'telephone']
# day
# [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24 25  1 10 22 31]
# month
# ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# duration
# [ 261  151   76 ... 1298 1246 1556]
# campaign
# ...

# %% [markdown]
# For job and martial columns we got some 'Unkown' values
# to remove them first, we consider them as NA values and then use mode to replace the values
# since the proportion of unknown is considerably small

# %%
df['job'].replace('unknown',np.nan,inplace = True)
df['marital'].replace('unknown',np.nan,inplace = True)
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33           NaN    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.isnull().sum()
# Out:
# age            0
# job          288
# marital        0
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# contact        0
# day            0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# poutcome       0
# deposit        0
# dtype: int64

# %% [markdown]
# Now job has 288 null values.
#
# Next, we will be replacing NA values with the Mode.

# %%
df['job'].replace(np.NAN , df['job'].mode()[0] , inplace=True)
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33   blue-collar    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [raw]
# Checking again the null values.

# %%
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %% [markdown]
# # Checking the outlier and skewness

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
sns.boxplot('balance' , hue = 'deposit' , data =df)

plt.subplot(3,2,2)
sns.boxplot('duration' , hue = 'deposit' , data =df)

plt.subplot(3,2,3)
sns.boxplot('campaign' , hue = 'deposit' , data =df)

plt.subplot(3,2,4)
sns.boxplot('pdays' , hue = 'deposit' , data =df)

plt.subplot(3,2,5)
sns.boxplot('previous' , hue = 'deposit' , data =df)
# Out:
# C:\Users\Shouq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Shouq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Shouq\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
plt.figure(figsize=(10,10))
plt.subplot(3,2,1)
sns.distplot(df.balance)

plt.subplot(3,2,2)
sns.distplot(df.duration)

plt.subplot(3,2,3)
sns.distplot(df.campaign)

plt.subplot(3,2,4)
sns.distplot(df.pdays)

plt.subplot(3,2,5)
sns.distplot(df.previous)
# Out:
# C:\Users\Shouq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Shouq\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# # Explortory Data Analysis

# %% [markdown]
# ### How does the categorical values affect the possibility of selling term deposit?

# %%
df.pivot_table(index='job',columns='deposit',aggfunc='size').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='job'>

# %%
df.pivot_table(index='marital',columns='deposit',aggfunc='size').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='marital'>

# %%
df.pivot_table(index='education',columns='deposit',aggfunc='size').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='education'>

# %%
df.pivot_table(index='contact',columns='deposit',aggfunc='size').plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='contact'>

# %% [markdown]
# ### How does the numerical values affect the possibility of selling term deposit?

# %%
df.groupby('deposit').balance.agg(['min','max','mean','std']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='deposit'>

# %%
df.groupby('deposit').duration.agg(['min','max','mean','std']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='deposit'>

# %%
df.groupby('deposit').duration.describe()
# Out:
#            count        mean         std  min    25%    50%    75%     max
# deposit
# no       39922.0  221.182806  207.383237  0.0   95.0  164.0  279.0  4918.0
# yes       5289.0  537.294574  392.525262  8.0  244.0  426.0  725.0  3881.0

# %%
df.groupby('deposit').pdays.agg(['min','max','mean','std']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='deposit'>

# %%
df.groupby('deposit').campaign.agg(['min','max','mean','std']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='deposit'>

# %%
df.groupby('deposit').previous.agg(['min','max','mean','std']).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='deposit'>
